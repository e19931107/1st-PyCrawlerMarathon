# %%
1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
# Out:
#   File "<ipython-input-1-8f5dd1f9392f>", line 1
#     1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
#         ^
# SyntaxError: invalid syntax

# %%
import requests
import json

url='https://www.dcard.tw/_api/forums/pet/posts?popular=true'
reqs = requests.get(url)

reqsjson = json.loads(reqs.text)

m = reqsjson[0]
print('回傳的資料有哪些欄位:')
print(m.keys())

print('\n\n回傳幾筆資料:')
print(len(m))
# Out:
# 回傳的資料有哪些欄位:
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
#
#
# 回傳幾筆資料:
# 32

# %%
import requests
# 引入函式庫

r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
# 想要爬資料的目標網址

response = r.text
# 模擬發送請求的動作

print(response)
# Out:
# [{"id":232693665,"title":"#圖多 口香糖做的貓？！","excerpt":"雖然從小就很黏人，不過有段時間他都會自己睡貓窩或是某個地方休息，最近！真的不管我到哪他就到哪，而且還怎麼吵他他都不走🤣，剛剛用電腦就一直守在旁邊？跟他玩完他在我旁邊休息🥰，前天早上 睡醒發現被蚊子","anonymousSchool":false,"anonymousDepartment":true,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2019-12-15T19:26:51.944Z","updatedAt":"2019-12-15T19:26:51.944Z","commentCount":15,"likeCount":396,"withNickname":false,"tags":[],"topics":["貓","口香糖","寵物","可愛","終養不棄養"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"F","school":"臺北城市科技大學","replyTitle":null,"mediaMeta":[{"id":"3a278b36-c250-4a27-a798-f6c96d5818bf","url":"https://i.imgur.com/spAy4w9l.jpg","normalizedUrl":"https://i.imgur.com/spAy4w9l.jpg","thumbnail":"https://i.imgur.com/spAy4w9l.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2019-12-15T19:26:51.944Z","updatedAt":"2019-12-15T19:26:51.944Z"},{"id":"3a278b36-c250-4a27-a798-f6c96d5818bf","url":"https://i.imgur.com/spAy4w9.jpg","normalizedUr
# ...

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

import json

data = json.loads(response) 
# 利用 json 解析網⾴內容

print('---------------------------------------------\n\n取出每⼀一篇⽂文章的標題:\n')
for d in data:
    print(d['title']) # 取出每⼀一篇⽂文章的標題

print('---------------------------------------------\n\n取出每⼀一篇⽂文章的貼文時間:\n')
for d in data:
    print(d['createdAt'])

print('---------------------------------------------\n\n取出每⼀一篇⽂文章的留言人數:\n')
for d in data:
    print(d['commentCount'])

print('---------------------------------------------\n\n取出每⼀一篇⽂文章的按讚人數:\n')
for d in data:
    print(d['likeCount'])
# Out:
# ---------------------------------------------
#
# 取出每⼀一篇⽂文章的標題:
#
# #圖多 口香糖做的貓？！
# 超級黏爸的傲嬌貓貓🐈
# #黑特 小孩虐待寵物活活踩死鸚鵡
# 給不給人出門
# 我爸想喂野貓吃農藥
# 阿嬤養的豬
# 還我男朋友ಠ_ಠ
# 我家柯基在思考人生
# 原以為會很可愛卻走鐘了
# #英短 我可愛的兒💖
# 台南有好心人收養貓咪嗎底下留言貓咪太多了
# 狗狗在我面前的離逝...拜託有良心一點！！！
# 新北耶誕城～真的很抱歉🙇‍♀️🙇
# #急尋 我的狗狗出車禍被帶走
# 轉：《轉》新竹市巨城附近大量小貓慘死
# 貓咪吃到酸梅🐈😝😖 (圖)
# 我努力賺錢，你努力花錢😭
# 同學，交出妳的貓咪
# 偽長大照
# 寵物鮮食 狗蛋糕
# #圖 重點色布偶喔！不是暹羅ヾ(*ΦωΦ)ツ
# #天竺鼠 Fatbe Diary 成長日記 - 鼻鼻討摸摸睡著篇
# 你可以不要這麼厭世嗎
# 獸醫助理
# 送養？棄養？
# 求救，我好擔心……
# 守宮的腹部🦎
# 今天坐火車看到的🐱
# 我的貓走失了😭
# 急）板橋附近誘捕籠租借
# ---------------------------------------------
#
# 取出每⼀一篇⽂文章的貼文時間:
#
# 2019-12-15T19:26:51.944Z
# 2019-12-15T00:52:33.602Z
# 2019-12-15T15:32:42.755Z
# 2019-12-15T13:07:06.980Z
# 2019-12-15T04:20:43.807Z
# 2019-12-15T17:16:31.445Z
# 2019-12-15T17:25:24.041Z
# 2019-12-15T12:17:53.947Z
# 2019-12-15T13:46:03.332Z
# 2019-12-15T10:38:42.587Z
# 2019-12-14T23:22:33.728Z
# 2019-12-16T03:35:00.754Z
# 2019-12-16T03:20:30.036Z
# 2019-12-16T05:41:30.837Z
# 2019-12-15T14:36:22.125Z
# ...

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

#熱門文章
hot = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
data = json.loads(response)

#熱門文章總留言人數
sum = 0
for d in data:
    n = int(d['commentCount'])
    sum = sum+n

#熱門文章平均留言人數
m = len(data)
print('熱門文章平均留言人數:')
print(sum/m)



#熱門文章總按讚人數
sum = 0
for d in data:
    n = d['likeCount']
    sum = sum+n

#熱門文章平均按讚人數
m = len(data)
print('\n\n熱門文章平均按讚人數:')
print(sum/m)
# Out:
# 熱門文章平均留言人數:
# 6.1
#
#
# 熱門文章平均按讚人數:
# 38.1

# %%
import requests
# 引入函式庫

r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')
# 想要爬資料的目標網址

response = r.text
# 模擬發送請求的動作

#print(response)

# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

import json

data = json.loads(response) 
# 利用 json 解析網⾴內容

# print('---------------------------------------------\n\n取出每⼀一篇⽂文章的標題:\n')
# for d in data:
#     print(d['title']) # 取出每⼀一篇⽂文章的標題

# print('---------------------------------------------\n\n取出每⼀一篇⽂文章的貼文時間:\n')
# for d in data:
#     print(d['createdAt'])

# print('---------------------------------------------\n\n取出每⼀一篇⽂文章的留言人數:\n')
# for d in data:
#     print(d['commentCount'])

# print('---------------------------------------------\n\n取出每⼀一篇⽂文章的按讚人數:\n')
# for d in data:
#     print(d['likeCount'])


#非熱門文章
nonhot = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')
data = json.loads(response)

#非熱門文章總留言人數
sums = 0
for d in data:
    n = d['commentCount']
    sums = sums+n

#非熱門文章平均留言人數
m = len(data)
print('非熱門文章平均留言人數:')
print(sums/m)



#熱門文章總按讚人數
sums = 0
for d in data:
    n = d['likeCount']
    sums = sums+n

#熱門文章平均按讚人數
m = len(data)
print('\n\n非熱門文章平均按讚人數:')
print(sums/m)
# Out:
# 非熱門文章平均留言人數:
# 2.7666666666666666
#
#
# 非熱門文章平均按讚人數:
# 25.366666666666667
